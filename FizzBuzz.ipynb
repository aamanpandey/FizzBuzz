# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# Print out a sequence of numbers 1,2,…,99 on multiples of 5 print Fizz instead of the number.
# On multiples of 7 print Buzz instead of the number.
# At 35 or any multiple of both, print FizzBuzz

# %%
x = 99

for i in range(1,x+1):
    if i%5==0 and i %7==0:
        print('FizzBuzz')
    if i%5==0:
        print('Fizz')
    elif i%7==0:
        print('Buzz')
    elif i%5!=0: print(i)
# Out:
# 1
# 2
# 3
# 4
# Fizz
# 6
# Buzz
# 8
# 9
# Fizz
# 11
# 12
# 13
# Buzz
# Fizz
# 16
# 17
# 18
# 19
# Fizz
# Buzz
# 22
# 23
# 24
# Fizz
# 26
# 27
# Buzz
# 29
# Fizz
# 31
# 32
# 33
# 34
# FizzBuzz
# Fizz
# 36
# 37
# 38
# 39
# Fizz
# 41
# Buzz
# 43
# 44
# Fizz
# 46
# 47
# 48
# Buzz
# Fizz
# 51
# 52
# 53
# 54
# Fizz
# Buzz
# 57
# 58
# 59
# Fizz
# 61
# 62
# Buzz
# 64
# Fizz
# 66
# 67
# 68
# 69
# FizzBuzz
# Fizz
# 71
# 72
# 73
# 74
# Fizz
# 76
# Buzz
# 78
# 79
# Fizz
# 81
# 82
# 83
# Buzz
# Fizz
# 86
# 87
# 88
# 89
# Fizz
# Buzz
# 92
# 93
# 94
# Fizz
# 96
# 97
# Buzz
# 99
